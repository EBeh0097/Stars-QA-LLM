# %% [markdown]
# ##Installing libraries

# %%
# %%capture
# !pip install -U sentence-transformers

# %% [markdown]
# ## Importing libraries

# %%
from sentence_transformers import SentenceTransformer
import pandas as pd
import numpy as np
# import nltk
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ## Information Retrieval using cross-encoder/ms-marco-MiniLM-L6-v2'

# %%
# %%capture
# !pip install -U sentence-transformers

# %%
from sentence_transformers import CrossEncoder

model = CrossEncoder('cross-encoder/ms-marco-MiniLM-L6-v2')

# %%
# !pip install pymupdf  # Install the library

import fitz  # PyMuPDF

def read_pdf_paragraphs(file_path):
    doc = fitz.open(file_path)
    text = ""
    for page in doc:
        text += page.get_text() + "\n"  # Collect text with spacing

    paragraphs = [para.strip() for para in text.split("\n\n") if para.strip()]  # Split and clean paragraphs
    return paragraphs

# Example usage
pdf_pages = read_pdf_paragraphs("2025_tech_notes_2024_10_03_0.pdf")
print(pdf_pages)
# Out:
# ...
# ['Medicare \n2025 Part C & D \nStar Ratings \nTechnical Notes \n \nUpdated – 10/03/2024', '(Last Updated 10/03/2024)  \nPage i \n \nDocument Change Log \nPrevious \nVersion \nDescription of Change \nRevision \nDate \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \nOMB Approved Data Sources \nThe data collected for the Part C & D Star Ratings come from a variety of different data sources approved under \nthe following Office of Management and Budget (OMB) Paperwork Reduction Act numbers: \nData Source \nOMB Number \nConsumer Assessment of Healthcare Providers and Systems (CAHPS) Surveys 0938-0732 \nHealth Outcomes Survey (HOS) \n0938-0701 \nHealthcare Effectiveness Data and Information Set (HEDIS) \n0938-1028 \nPart C Reporting Requirements \n0938-1054 \nPart D Reporting Requirements \n0938-0992 \nData Validation of Part C/D Reporting Requirements data \n0938-1115', '(Last Updated 10/03/2024)  \nPage ii \n \nTable of Contents \nDOCUME
# ...

# %%
# abstracts_small = np.array(Df[:], dtype=object, ndmin = 1)

# %%
Df = np.array(pdf_pages[:], dtype=object, ndmin = 1)

# %%
Df[7]
# Out:
# '(Last Updated 10/03/2024)  \nPage vii \n \nATTACHMENT S: HEALTH PLAN MANAGEMENT SYSTEM MODULE REFERENCE ............................... 190 \nHPMS Star Ratings Module ........................................................................................................................................... 190 \n1. Measure Data page ................................................................................................................................................... 190 \nTable S-1: Measure Data page sample .......................................................................................................................... 190 \n2. Measure Detail – CTM Summary page ..................................................................................................................... 190 \nTable S-2: Measure Detail – CTM Summary page fields ................................................................................................ 191 \n3. Measure Detail – Part C A
# ...

# %%
Df1 = Df
Df1[29]
# Out:
# '(Last Updated 10/03/2024)  \nPage 22 \n \nTable 20: Categorization of Contract’s Members into Quartiles of Disability for the PDP Part D Summary \nDisability Quartile \nPercentage of Contract’s \nBeneficiaries who are Disabled \n1 \n \n0.000000 to less than 6.593595 \n2 \n6.593595 to less than 10.621062 \n3 \n \n10.621062 to less than 14.589481 \n4 \n \n14.589481 to 100.000000 \n \nTable 21 provides the description of each of the final adjustment categories for the PDP Part D summary and \nthe associated value of the CAI per final adjustment category. Note that the CAI values for the PDP Part D \nsummary are different from the CAI values for the MA-PD Part D summary. There are three final adjustment \ncategories for the PDP Part D summary. \n \nTable 21: Final Adjustment Categories and CAI Values for the PDP Part D Summary \nFinal Adjustment \nCategory \nLIS/DE Quartile \nDisability Quartile \nCAI Value \n1 \nL1-L2 \nD1-D2 \n-0.230036 \n2 \nL1-L3 \nD3-D4 \n-0.081240 \n  \nL3-L4 \nD1
# ...

# %%
len(Df1)
# Out:
# 214

# %%
#Question 1

Question1 = ["What is (CAI)?"] * len(Df)
Question_list_1 = list((zip(Question1, Df)))
Question_list_1[40:41]

#Question 2

Question2 = ["What is BCS, describe what BCS stand for? or What measure it is?"] * len(Df)
Question_list_2 = list((zip(Question2, Df)))
Question_list_2[30:31]

#Question 3

Question3 = ["CBP calculation?"] * len(Df)
Question_list_3 = list((zip(Question3, Df)))
Question_list_3[20:21]

#Question 4

Question4 = ["Changes for rating year 2025 compared to rating year 2024?"] * len(Df)
Question_list_4 = list((zip(Question4, Df)))
Question_list_4[50:51]

#Question 5

Question5 = ["What is clustering?"] * len(Df)
Question_list_5 = list((zip(Question5, Df)))
Question_list_5[60:61]
# Out:
# [('What is clustering?',
# ...

# %%
# Question_list = []
# Question = ["Describe (CAI) Categorical Adjustment Index?"]
# x = False
# i = 21
# while not x:
#   b = Df1[i]
#   B = Question + [b]
#   Question_list.append(B)
#   i = i + 1
#   if i == 25:
#     x = True
# print(Question_list) # Print the tuple if needed

# %%
# Question_list[]

# %%
#Question 1 score
scores1 = model.predict(Question_list_1[:])
print(scores1[4])

#Question 2 score
scores2 = model.predict(Question_list_2[:])
print(scores2[4])

#Question 3 score
scores3 = model.predict(Question_list_3[:])
print(scores3[4])

#Question 4 score
scores4 = model.predict(Question_list_4[:])
print(scores4[4])

#Question 5 score
scores5 = model.predict(Question_list_5[:])
print(scores5[4])
# Out:
# -8.940077
# -8.416224
# -9.202217
# -4.328757
# -9.698146

# %%
# sorted for score1
sorted_array1 = np.sort(scores1[:])
print("sorted_array: ", sorted_array1[4])

# sorted for score2
sorted_array2 = np.sort(scores2[:])
print("sorted_array: ", sorted_array2[4])

# sorted for score3
sorted_array3 = np.sort(scores3[:])
print("sorted_array: ", sorted_array3[4])

# sorted for score4
sorted_array4 = np.sort(scores4[:])
print("sorted_array: ", sorted_array4[4])

# sorted for score5
sorted_array5 = np.sort(scores5[:])
print("sorted_array: ", sorted_array5[4])
# Out:
# sorted_array:  -11.322069
# sorted_array:  -11.135099
# sorted_array:  -10.804609
# sorted_array:  -8.243604
# sorted_array:  -11.397772

# %%
# sorted for descending sort1
descending_order_array1 = sorted_array1[::-1]
print("descending_array: ", descending_order_array1[4])

# sorted for descending sort2
descending_order_array2 = sorted_array2[::-1]
print("descending_array: ", descending_order_array2[4])

# sorted for descending sort3
descending_order_array3 = sorted_array3[::-1]
print("descending_array: ", descending_order_array3[4])

# sorted for descending sort4
descending_order_array4 = sorted_array4[::-1]
print("descending_array: ", descending_order_array4[4])

# sorted for descending sort5
descending_order_array5 = sorted_array5[::-1]
print("descending_array: ", descending_order_array5[4])
# Out:
# descending_array:  -2.8424182
# descending_array:  -5.6528134
# descending_array:  -4.7711406
# descending_array:  0.7878732
# descending_array:  -1.6613616

# %%
# descending indices sort 1
ascending_indices1 = scores1[:].argsort()
descending_indices1 = ascending_indices1[::-1]
print("with stopwrods descending_indices: ", descending_indices1)

# descending indices sort 2
ascending_indices2 = scores2[:].argsort()
descending_indices2 = ascending_indices2[::-1]
print("with stopwrods descending_indices: ", descending_indices2)

# descending indices sort 3
ascending_indices3 = scores3[:].argsort()
descending_indices3 = ascending_indices3[::-1]
print("with stopwrods descending_indices: ", descending_indices3)


# descending indices sort 4
ascending_indices4 = scores4[:].argsort()
descending_indices4 = ascending_indices4[::-1]
print("with stopwrods descending_indices: ", descending_indices4)

# descending indices sort 5
ascending_indices5 = scores5[:].argsort()
descending_indices5 = ascending_indices5[::-1]
print("with stopwrods descending_indices: ", descending_indices5)
# Out:
# with stopwrods descending_indices:  [177  24  86  23  35  68 205  29  20  43  96  61 211  81  27  83  78  71
#   58  90 104   3  40  52 107  47  93 210  25  69  91  28  50  66 178  79
#   62  26  54  98 179  59  64  84  48  94  73  45  16 108  72  76 153  56
#    2 193 112  74 102 150   7 194   6 195  87   4 187 134  38 154  17  14
#   32 106 100  53  99 163   8  55   5 113 161  65  82 103 111 188 133  15
#  209 171 152 110 105 181 160  44  12 198 186  80  51 191 129  67 185  21
#   37  10 208  39 201 162 180  75 206 166 126 204  31  92 170  13 207  63
#   77 167  18 136  97  30 168 151 165  36  89 158  95  49  46 197  57 135
#   42 203 189 109 159 175 127  19  41 173 155  22 202 121 196 172 199 101
#  212 182 143  85 192 183 156 142 190 137 200 132 138 118 141  11 122  70
#  120 116 176 145 149 213 130 124  33 146 184  60 115 164 117 140 147 148
#  114 139   9 119 131 128 157 144   1 174 123  88 125   0 169  34]
# ...

# %%
# top 5 retrieved text for question 1
top_3_indices1 = descending_indices1[:5]
print("top_3_indices: ", top_3_indices1)
for index in top_3_indices1:
  print("With stopwords embedding retrieved abstract : ",Question1[0],'\n',Df1[index], '\n')
# Out:
# top_3_indices:  [177  24  86  23  35]
# With stopwords embedding retrieved abstract :  What is (CAI)?
#  (Last Updated 10/03/2024)
# Page 170
#
# Attachment O: Methodology for the Puerto Rico Model
# Puerto Rico has a unique health care market with a large percentage of low-income individuals in both
# Medicare and Medicaid and a complex legal history that affects the health care system in many ways. Puerto
# Rican beneficiaries are not eligible for LIS. The categorization of contracts into final adjustment categories for
# the Categorical Adjustment Index (CAI) relies on both the use of a contract’s percentages of beneficiaries with
# Low Income Subsidy/Dual Eligible (LIS/DE) and disabled beneficiaries.  Since the percentage of LIS/DE is a
# critical element in the categorization of contracts to identify the contract’s CAI, an additional adjustment is
# done for contracts that solely serve the population of beneficiaries in Puerto Rico to address the lack of LIS. The
# ...

# %%
# top 5 retrieved text for question 2
top_3_indices2 = descending_indices2[:5]
print("top_3_indices: ", top_3_indices2)
for index in top_3_indices2:
  print("With stopwords embedding retrieved abstract : ",Question2[0],'\n',Df1[index], '\n')
# Out:
# top_3_indices:  [ 37 121  36 108 150]
# With stopwords embedding retrieved abstract :  What is BCS, describe what BCS stand for? or What measure it is?
#  (Last Updated 10/03/2024)
# Page 30
#
# Part C Domain and Measure Details
# See Attachment C for the national averages of individual Part C measures.
# Domain: 1 - Staying Healthy: Screenings, Tests and Vaccines
# Measure: C01 - Breast Cancer Screening
# Title
# Description
# Label for Stars: Breast Cancer Screening
# Label for Data: Breast Cancer Screening
# Description: Percent of female plan members aged 52-74 who had a mammogram during the past
# two years.
# HEDIS Label: Breast Cancer Screening (BCS)
# Measure Reference: NCQA HEDIS Measurement Year 2023 Technical Specifications Volume 2, page 606
# Metric: The percentage of women MA enrollees 50 to 74 years of age (denominator) as of
# December 31 of the measurement year who had a mammogram to screen for breast
# cancer in the past two years (numerator).
# ...

# %%
# top_3_indices
# paragraph = Df1[top_3_indices[0]]
# print(paragraph)

# %%
# top 5 retrieved text for question 3
top_3_indices3 = descending_indices3[:5]
print("top_3_indices: ", top_3_indices3)
for index in top_3_indices3:
  print("With stopwords embedding retrieved abstract : ",Question3[0],'\n',Df1[index], '\n')
# Out:
# top_3_indices:  [ 55 101 129  93 104]
# With stopwords embedding retrieved abstract :  CBP calculation?
#  (Last Updated 10/03/2024)
# Page 48
#
# Measure: C11 - Controlling Blood Pressure
# Title
# Description
# Label for Stars: Controlling Blood Pressure
# Label for Data: Controlling Blood Pressure
# Description: Percent of plan members with high blood pressure who got treatment and were able to
# maintain a healthy pressure.
# HEDIS Label: Controlling High Blood Pressure (CBP)
# Measure Reference: NCQA HEDIS MY 2023 Technical Specifications Volume 2, page 152
# Metric: The percentage of MA members 18–85 years of age who had a diagnosis of
# hypertension (HTN) (denominator) and whose blood pressure (BP) was adequately
# controlled (<140/90 mm Hg) (numerator).
# Primary Data Source: HEDIS
# Data Source Category: Health and Drug Plans
# Exclusions: Exclude members who meet any of the following criteria:
# ...

# %%
# top 5 retrieved text for question 4
top_3_indices4 = descending_indices4[:5]
print("top_3_indices: ", top_3_indices4)
for index in top_3_indices4:
  print("With stopwords embedding retrieved abstract : ",Question4[0],'\n',Df1[index], '\n')
# Out:
# top_3_indices:  [133   9 135  15 134]
# With stopwords embedding retrieved abstract :  What changed in 2025 compared to 2024?
#  (Last Updated 10/03/2024)
# Page 126
#
# Attachment I: Calculating the Improvement Measure and the Measures Used
# Calculating the Improvement Measure
# Contracts must have data for at least half of the attainment measures used to calculate the Part C or Part D
# improvement measure to be eligible to receive a rating in that improvement measure.
# The improvement change score was determined for each measure for which a contract was eligible by
# calculating the difference in measure scores between Star Rating years 2024 and 2025.
# For measures where a higher score is better:
# Improvement Change Score = Score in 2025 - Score in 2024
# For measures where a lower score is better:
# Improvement Change Score = Score in 2024 - Score in 2025
# An eligible measure was defined as a measure for which a contract was scored in both the 2024 and 2025 Star
# ...

# %%
# top 5 retrieved text for question 5
top_3_indices5 = descending_indices5[:5]
print("top_3_indices: ", top_3_indices5)
for index in top_3_indices5:
  print("With stopwords embedding retrieved abstract : ",Question5[0],'\n',Df1[index], '\n')
# Out:
# top_3_indices:  [150  16 152 154 153]
# With stopwords embedding retrieved abstract :  What is clustering?
#  (Last Updated 10/03/2024)
# Page 143
#
# Attachment K: Individual Measure Star Assignment Process
# This attachment provides detailed information about the clustering and the relative distribution and significance
# testing (CAHPS) methodologies used to assign stars to individual measures.
# Clustering Methodology Introduction
# To separate a distribution of scores into distinct groups or categories, a set of values must be identified to
# separate one group from another group. The set of values that break the distribution of the scores into non-
# overlapping groups is the set of cut points.
# For each individual measure, CMS determines the measure cut points using the information provided from the
# hierarchical clustering algorithm in SAS, described in “Clustering Methodology Detail” below. Conceptually,
# ...

# %%
# %%capture
# !pip install transformers

# %% [markdown]
# ## Question Answering with bert and roberta

# %%
# %%capture
# !pip install pymupdf  # Install the library

# %%
# !pip install pymupdf  # Install the library

import fitz  # PyMuPDF

def read_pdf_paragraphs(file_path):
    doc = fitz.open(file_path)
    text = ""
    for page in doc:
        text += page.get_text() + "\n"  # Collect text with spacing

    paragraphs = [para.strip() for para in text.split("\n\n") if para.strip()]  # Split and clean paragraphs
    return paragraphs

# Example usage
pdf_pages = read_pdf_paragraphs("2025_tech_notes_2024_10_03_0.pdf")
print(pdf_pages)
# Out:
# ['Medicare \n2025 Part C & D \nStar Ratings \nTechnical Notes \n \nUpdated – 10/03/2024', '(Last Updated 10/03/2024)  \nPage i \n \nDocument Change Log \nPrevious \nVersion \nDescription of Change \nRevision \nDate \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \nOMB Approved Data Sources \nThe data collected for the Part C & D Star Ratings come from a variety of different data sources approved under \nthe following Office of Management and Budget (OMB) Paperwork Reduction Act numbers: \nData Source \nOMB Number \nConsumer Assessment of Healthcare Providers and Systems (CAHPS) Surveys 0938-0732 \nHealth Outcomes Survey (HOS) \n0938-0701 \nHealthcare Effectiveness Data and Information Set (HEDIS) \n0938-1028 \nPart C Reporting Requirements \n0938-1054 \nPart D Reporting Requirements \n0938-0992 \nData Validation of Part C/D Reporting Requirements data \n0938-1115', '(Last Updated 10/03/2024)  \nPage ii \n \nTable of Contents \nDOCUME
# ...

# %%
print(pdf_pages[18])
# Out:
# (Last Updated 10/03/2024)
# Page 11
#
# Table 5: Minimum Number of Rated Measures Required for a Domain Rating by Contract Type
# Part
# Domain Name (Identifier)
# 1876
# Cost †
# CCP
# w/o SNP
# CCP
# with SNP
# CCP with
# Only I-SNP
# MSA
# PDP
# PFFS
# C
# Staying Healthy: Screenings,
# Tests and Vaccines (HD1)
# 3 of 4
# 3 of 4
# 3 of 4
# 2 of 2
# 3 of 4
# N/A
# 3 of 4
# C
# Managing Chronic (Long
# Term) Conditions (HD2)
# 5 of 8
# 6 of 11
# 8 of 14
# 6 of 10
# 6 of 11
# N/A
# 6 of 11
# C
# Member Experience with
# Health Plan (HD3)
# 4 of 6
# 4 of 6
# 4 of 6
# N/A
# 4 of 6
# N/A
# 4 of 6
# C
# Member Complaints and
# Changes in the Health Plan's
# Performance (HD4)
# 2 of 3
# 2 of 3
# 2 of 3
# 2 of 3
# 2 of 3
# N/A
# 2 of 3
# C
# Health Plan Customer
# Service (HD5)
# 2 of 2
# 2 of 3
# 2 of 3
# 2 of 3
# 2 of 2
# N/A
# 2 of 3
# D
# Drug Plan Customer Service
# (DD1)
# N/A*
# 1 of 1
# 1 of 1
# 1 of 1
# N/A
# 1 of 1
# 1 of 1*
# D
# Member Complaints and
# ...

# %%
#Keeping Questions the same
question1 = Question1[0]
question2 = Question2[0]
question3 = Question3[0]
question4 = Question4[0]
question5 = Question5[0]
question5
# Out:
# 'What is clustering?'

# %%
#Question 1 paragraph
a1 = [top_3_indices1[0]]
a1
paragraph1 = Df1[a1[0]]
print(paragraph1,'/n')

#Question 2 paragraph
a2 = [top_3_indices2[0]]
a2
paragraph2 = Df1[a2[0]]
print(paragraph2,'/n')

#Question 3 paragraph
a3 = [top_3_indices3[0]]
a3
paragraph3 = Df1[a3[0]]
print(paragraph3,'/n')

#Question 4 paragraph
a4 = [top_3_indices4[0]]
a4
paragraph4 = Df1[a4[0]]
print(paragraph4,'/n')

#Question 5 paragraph
a5 = [top_3_indices5[0]]
a5
paragraph5 = Df1[a5[0]]
print(paragraph5, '/n')
# Out:
# (Last Updated 10/03/2024)
# Page 170
#
# Attachment O: Methodology for the Puerto Rico Model
# Puerto Rico has a unique health care market with a large percentage of low-income individuals in both
# Medicare and Medicaid and a complex legal history that affects the health care system in many ways. Puerto
# Rican beneficiaries are not eligible for LIS. The categorization of contracts into final adjustment categories for
# the Categorical Adjustment Index (CAI) relies on both the use of a contract’s percentages of beneficiaries with
# Low Income Subsidy/Dual Eligible (LIS/DE) and disabled beneficiaries.  Since the percentage of LIS/DE is a
# critical element in the categorization of contracts to identify the contract’s CAI, an additional adjustment is
# done for contracts that solely serve the population of beneficiaries in Puerto Rico to address the lack of LIS. The
# additional analysis for the adjustment results in a modified percentage of LIS/DE beneficiaries that is
# ...

# %%
from transformers import AutoTokenizer, AutoModelForQuestionAnswering
import torch

model = AutoModelForQuestionAnswering.from_pretrained("deepset/roberta-base-squad2")
tokenizer = AutoTokenizer.from_pretrained("deepset/roberta-base-squad2")

from transformers import AutoTokenizer, AutoModelForQuestionAnswering
import torch

model = AutoModelForQuestionAnswering.from_pretrained("deepset/roberta-base-squad2")
tokenizer = AutoTokenizer.from_pretrained("deepset/roberta-base-squad2")
# Answer for question 1
question = question1 # Added a question for demonstration. Replace with your actual question variable.
context = paragraph1 # Added a context for demonstration. Replace with your actual context variable.
inputs = tokenizer(question, context, return_tensors="pt", truncation=True, max_length=512)
with torch.no_grad():
    outputs = model(**inputs)

answer_start_index = outputs.start_logits.argmax()
answer_end_index = outputs.end_logits.argmax()

answer_tokens = inputs.input_ids[0, answer_start_index : answer_end_index + 1]
print(question, "/n")
print(tokenizer.decode(answer_tokens))
print('\n',paragraph1)
# Out:
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/496M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/79.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/772 [00:00<?, ?B/s]
# What is (CAI)? /n
#  Categorical Adjustment Index
#
#  (Last Updated 10/03/2024)
# Page 170
#
# Attachment O: Methodology for the Puerto Rico Model
# Puerto Rico has a unique health care market with a large percentage of low-income individuals in both
# Medicare and Medicaid and a complex legal history that affects the health care system in many ways. Puerto
# Rican beneficiaries are not eligible for LIS. The categorization of contracts into final adjustment categories for
# the Categorical Adjustment Index (CAI) relies on both the use of a contract’s percentages of beneficiaries with
# ...

# %%
# answer for question 2
question = question2 # Added a question for demonstration. Replace with your actual question variable.
context = paragraph2 # Added a context for demonstration. Replace with your actual context variable.
inputs = tokenizer(question, context, return_tensors="pt", truncation=True, max_length=512)
with torch.no_grad():
    outputs = model(**inputs)

answer_start_index = outputs.start_logits.argmax()
answer_end_index = outputs.end_logits.argmax()

answer_tokens = inputs.input_ids[0, answer_start_index : answer_end_index + 1]
print(question, "/n")
print(tokenizer.decode(answer_tokens))
print('\n',paragraph2)
# Out:
# What is BCS, describe what BCS stand for? or What measure it is? /n
#  Breast Cancer Screening
#
#  (Last Updated 10/03/2024)
# Page 30
#
# Part C Domain and Measure Details
# See Attachment C for the national averages of individual Part C measures.
# Domain: 1 - Staying Healthy: Screenings, Tests and Vaccines
# Measure: C01 - Breast Cancer Screening
# Title
# Description
# Label for Stars: Breast Cancer Screening
# Label for Data: Breast Cancer Screening
# Description: Percent of female plan members aged 52-74 who had a mammogram during the past
# two years.
# HEDIS Label: Breast Cancer Screening (BCS)
# Measure Reference: NCQA HEDIS Measurement Year 2023 Technical Specifications Volume 2, page 606
# Metric: The percentage of women MA enrollees 50 to 74 years of age (denominator) as of
# December 31 of the measurement year who had a mammogram to screen for breast
# cancer in the past two years (numerator).
# Primary Data Source: HEDIS
# Data Source Category: Health and Drug Plans
# ...

# %%
# answer for question 3
question = question3 # Added a question for demonstration. Replace with your actual question variable.
context = paragraph3 # Added a context for demonstration. Replace with your actual context variable.
inputs = tokenizer(question, context, return_tensors="pt", truncation=True, max_length=512)
with torch.no_grad():
    outputs = model(**inputs)

answer_start_index = outputs.start_logits.argmax()
answer_end_index = outputs.end_logits.argmax()

answer_tokens = inputs.input_ids[0, answer_start_index : answer_end_index + 1]
print(question, "/n")
print(tokenizer.decode(answer_tokens))
print('\n',paragraph3)
# Out:
# CBP calculation? /n
# <s>
#
#  (Last Updated 10/03/2024)
# Page 48
#
# Measure: C11 - Controlling Blood Pressure
# Title
# Description
# Label for Stars: Controlling Blood Pressure
# Label for Data: Controlling Blood Pressure
# Description: Percent of plan members with high blood pressure who got treatment and were able to
# maintain a healthy pressure.
# HEDIS Label: Controlling High Blood Pressure (CBP)
# Measure Reference: NCQA HEDIS MY 2023 Technical Specifications Volume 2, page 152
# Metric: The percentage of MA members 18–85 years of age who had a diagnosis of
# hypertension (HTN) (denominator) and whose blood pressure (BP) was adequately
# controlled (<140/90 mm Hg) (numerator).
# Primary Data Source: HEDIS
# Data Source Category: Health and Drug Plans
# Exclusions: Exclude members who meet any of the following criteria:
# • Members 66 years of age and older as of December 31 of the measurement year who
# meet either of the following:
# ...

# %%
# answer for question 4
question = 'What changed in star rating year 2025?' # Added a question for demonstration. Replace with your actual question variable.
context = paragraph4 # Added a context for demonstration. Replace with your actual context variable.
inputs = tokenizer(question, context, return_tensors="pt", truncation=True, max_length=512)
with torch.no_grad():
    outputs = model(**inputs)

answer_start_index = outputs.start_logits.argmax()
answer_end_index = outputs.end_logits.argmax()

answer_tokens = inputs.input_ids[0, answer_start_index : answer_end_index + 1]
print(question, "/n")
print(tokenizer.decode(answer_tokens))
print('\n',paragraph4)
# Out:
# What changed in star rating year 2025? /n
# <s>
#
#  (Last Updated 10/03/2024)
# Page 126
#
# Attachment I: Calculating the Improvement Measure and the Measures Used
# Calculating the Improvement Measure
# Contracts must have data for at least half of the attainment measures used to calculate the Part C or Part D
# improvement measure to be eligible to receive a rating in that improvement measure.
# The improvement change score was determined for each measure for which a contract was eligible by
# calculating the difference in measure scores between Star Rating years 2024 and 2025.
# For measures where a higher score is better:
# Improvement Change Score = Score in 2025 - Score in 2024
# For measures where a lower score is better:
# Improvement Change Score = Score in 2024 - Score in 2025
# An eligible measure was defined as a measure for which a contract was scored in both the 2024 and 2025 Star
# ...

# %%
# answer for question 5
question = question5 # Added a question for demonstration. Replace with your actual question variable.
context = paragraph5 # Added a context for demonstration. Replace with your actual context variable.
inputs = tokenizer(question, context, return_tensors="pt", truncation=True, max_length=512)
with torch.no_grad():
    outputs = model(**inputs)

answer_start_index = outputs.start_logits.argmax()
answer_end_index = outputs.end_logits.argmax()

answer_tokens = inputs.input_ids[0, answer_start_index : answer_end_index + 1]
print(question, "/n")
print(tokenizer.decode(answer_tokens))
print('\n',paragraph5)
# Out:
# What is clustering? /n
# <s>What is clustering?</s></s>(Last Updated 10/03/2024)
# Page 143
#
# Attachment K: Individual Measure Star Assignment Process
# This attachment provides detailed information about the clustering and the relative distribution and significance
# testing (CAHPS) methodologies used to assign stars to individual measures.
# Clustering Methodology Introduction
# To separate a distribution of scores into distinct groups or categories, a set of values must be identified to
# separate one group from another group. The set of values that break the distribution of the scores into non-
# overlapping groups is the set of cut points.
# For each individual measure, CMS determines the measure cut points using the information provided from the
# hierarchical clustering algorithm
#
#  (Last Updated 10/03/2024)
# Page 143
#
# Attachment K: Individual Measure Star Assignment Process
# ...

# %% [markdown]
# ## Fine-Tuned Distil-BERT Qeustion Answering

# %% [markdown]
# #### Installing Libraries

# %%
# %%capture
# !pip install datasets

# %%
# %%capture
# !pip install transformers

# %% [markdown]
# #### Import Libraries

# %%
from transformers import DistilBertForQuestionAnswering, DistilBertTokenizerFast, \
                         TrainingArguments, Trainer, default_data_collator, pipeline
from datasets import load_dataset
import os
os.environ["WANDB_DISABLED"] = "true"

# %%
qa_dataset = load_dataset("squad")
print(qa_dataset)
# Out:
# README.md:   0%|          | 0.00/7.62k [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/14.5M [00:00<?, ?B/s]
# validation-00000-of-00001.parquet:   0%|          | 0.00/1.82M [00:00<?, ?B/s]
# ...
# Generating validation split:   0%|          | 0/10570 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'title', 'context', 'question', 'answers'],
#         num_rows: 87599
#     })
#     validation: Dataset({
#         features: ['id', 'title', 'context', 'question', 'answers'],
#         num_rows: 10570
#     })
# })

# %%
qa_dataset["train"][0]
# Out:
# {'id': '5733be284776f41900661182',
#  'title': 'University_of_Notre_Dame',
#  'context': 'Architecturally, the school has a Catholic character. Atop the Main Building\'s gold dome is a golden statue of the Virgin Mary. Immediately in front of the Main Building and facing it, is a copper statue of Christ with arms upraised with the legend "Venite Ad Me Omnes". Next to the Main Building is the Basilica of the Sacred Heart. Immediately behind the basilica is the Grotto, a Marian place of prayer and reflection. It is a replica of the grotto at Lourdes, France where the Virgin Mary reputedly appeared to Saint Bernadette Soubirous in 1858. At the end of the main drive (and in a direct line that connects through 3 statues and the Gold Dome), is a simple, modern stone statue of Mary.',
#  'question': 'To whom did the Virgin Mary allegedly appear in 1858 in Lourdes France?',
#  'answers': {'text': ['Saint Bernadette Soubirous'], 'answer_start': [515]}}

# %%
tokenizer = DistilBertTokenizerFast.from_pretrained("distilbert-base-uncased")
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]

# %% [markdown]
# ## Data Preprocessing

# %%
def prepare_train_features(examples):
  tokenized_examples = tokenizer(
      examples["question"],
      examples["context"],
      truncation="only_second",
      max_length=384,
      stride=128,
      return_overflowing_tokens=True,
      return_offsets_mapping=True,
      padding="max_length"
  )

  sample_mapping = tokenized_examples.pop("overflow_to_sample_mapping")
  offset_mapping = tokenized_examples.pop("offset_mapping")

  tokenized_examples["start_positions"] = []
  tokenized_examples["end_positions"] = []

  for i, offsets in enumerate(offset_mapping):
    input_ids = tokenized_examples["input_ids"][i]
    cls_index = input_ids.index(tokenizer.cls_token_id)

    sequence_ids = tokenized_examples.sequence_ids(i)
    sample_index = sample_mapping[i]
    answers = examples["answers"][sample_index]

    if len(answers["answer_start"]) == 0:
      tokenized_examples["start_positions"].append(cls_index)
      tokenized_examples["end_positions"].append(cls_index)
    else:
      start_char = answers["answer_start"][0]
      end_char = start_char + len(answers["text"][0])

      token_start_index = 0
      while sequence_ids[token_start_index] != 1:
        token_start_index += 1

      token_end_index = len(input_ids) - 1
      while sequence_ids[token_end_index] != 1:
        token_end_index -= 1

      if not (offsets[token_start_index][0] <= start_char and offsets[token_end_index][1] >= end_char):
        tokenized_examples["start_positions"].append(cls_index)
        tokenized_examples["end_positions"].append(cls_index)
      else:
        while token_start_index < len(offsets) and offsets[token_start_index][0] <= start_char:
          token_start_index += 1
        start_position = token_start_index - 1

        while offsets[token_end_index][1] >= end_char:
          token_end_index -= 1
        end_position = token_end_index + 1

        tokenized_examples["start_positions"].append(start_position)
        tokenized_examples["end_positions"].append(end_position)
  return tokenized_examples

# %%
tokenized_squad = qa_dataset.map(
    prepare_train_features,
    batched=True,
    remove_columns=qa_dataset["train"].column_names
)
# Out:
# ...
# Map:   0%|          | 0/10570 [00:00<?, ? examples/s]

# %% [markdown]
# ### Loading the pre-trained Model

# %%
model = DistilBertForQuestionAnswering.from_pretrained("distilbert-base-uncased")
# Out:
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Some weights of DistilBertForQuestionAnswering were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['qa_outputs.bias', 'qa_outputs.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# ## Fined-tuning the Pre-trained Model

# %%
#Define the training arguments

training_args = TrainingArguments(
    output_dir='./results',          # output directory
    num_train_epochs=2,              # total number of training epochs
    per_device_train_batch_size=32,
    per_device_eval_batch_size=32,
    fp16=True,
    logging_steps=100,
    log_level='warning',
    save_strategy='epoch',
    eval_strategy='epoch',
    load_best_model_at_end=True,
)
# Out:
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).

# %%
#Define the trainer
trainer = Trainer(
    model = model,
    args = training_args,
    train_dataset = tokenized_squad["train"],
    eval_dataset = tokenized_squad["validation"],
    tokenizer = tokenizer,
    data_collator = default_data_collator
)
# Out:
# <ipython-input-51-b440e5f98e53>:2: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='5534' max='5534' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5534/5534 27:35, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.158500</td>
#       <td>1.149860</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.834800</td>
#       <td>1.105188</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=5534, training_loss=1.1525733418356092, metrics={'train_runtime': 1656.9242, 'train_samples_per_second': 106.853, 'train_steps_per_second': 3.34, 'total_flos': 1.7348902540849152e+16, 'train_loss': 1.1525733418356092, 'epoch': 2.0})

# %% [markdown]
# ### Saving the Fined-tuned model

# %%
# trainer.save_model()

# %% [markdown]
# ##Testing the Fined-tuned model

# %%
question = question1
context = paragraph1

# %%
# Question 1 answer


pipe = pipeline("question-answering", model=model, tokenizer=tokenizer)
pipe(question = question, context = context)
# Out:
# Device set to use cuda:0
# {'score': 0.7067930102348328,
#  'start': 424,
#  'end': 452,
#  'answer': 'Categorical Adjustment Index'}

# %%
# Question 2 answer

question = question2
context = paragraph2

pipe = pipeline("question-answering", model=model, tokenizer=tokenizer)
pipe(question = question, context = context)
# Out:
# Device set to use cuda:0
# {'score': 0.8328844308853149,
#  'start': 470,
#  'end': 493,
#  'answer': 'Breast Cancer Screening'}

# %%
# Question 3 answer

question = question3
context = paragraph3

pipe = pipeline("question-answering", model=model, tokenizer=tokenizer)
pipe(question = question, context = context)
# Out:
# Device set to use cuda:0
# {'score': 0.0027367128059267998,
#  'start': 332,
#  'end': 363,
#  'answer': 'Controlling High Blood Pressure'}

# %%
# Question 4 answer

question = question4
context = paragraph4

pipe = pipeline("question-answering", model=model, tokenizer=tokenizer)
pipe(question = question, context = context)
# Out:
# Device set to use cuda:0
# {'score': 0.12021833658218384,
#  'start': 578,
#  'end': 610,
#  'answer': 'Improvement\u2008Change\u2008Score\u2008=\u2008Score'}

# %%
# Question 5 answer

question = question5
context = paragraph5

pipe = pipeline("question-answering", model=model, tokenizer=tokenizer)
pipe(question = question, context = context)
# Out:
# Device set to use cuda:0
# {'score': 0.07295985519886017,
#  'start': 289,
#  'end': 397,
#  'answer': 'Clustering Methodology Introduction \nTo separate a distribution of scores into distinct groups or categories'}
